# %% [markdown]
# # Facial Keypoints Identification with Keras
# This model looks at taking advantage of the Kaggle facial keypoints detection dataset to identify more points on a face than the nose, for example the eyes and mouth.
#
# Sources: [here](https://medium.com/@baikaralkesha/face-detection-using-opencv-in-google-colaboratory-a7529a2bb921) and [here](https://www.tensorflow.org/alpha/tutorials/images/transfer_learning)

# %% [markdown]
# ## Installation
# We first need to install TensorFlow 1.12 because TensorFlow 1.13 countains a BatchNormalizationV1 layer that cannot be converted to TensorFlowJS

# %%
# !pip install tensorflow==1.12
# Out:
# Collecting tensorflow==1.12
#   Downloading https://files.pythonhosted.org/packages/22/cc/ca70b78087015d21c5f3f93694107f34ebccb3be9624385a911d4b52ecef/tensorflow-1.12.0-cp36-cp36m-manylinux1_x86_64.whl (83.1MB)
#     100% |████████████████████████████████| 83.1MB 374kB/s
# Requirement already satisfied: numpy>=1.13.3 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.12) (1.16.3)
# Requirement already satisfied: absl-py>=0.1.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.12) (0.7.1)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.12) (1.1.0)
# Requirement already satisfied: grpcio>=1.8.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.12) (1.15.0)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.12) (1.0.9)
# Requirement already satisfied: keras-applications>=1.0.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.12) (1.0.7)
# Requirement already satisfied: astor>=0.6.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.12) (0.7.1)
# Requirement already satisfied: gast>=0.2.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.12) (0.2.2)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.12) (1.12.0)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.12) (0.33.1)
# Collecting tensorboard<1.13.0,>=1.12.0 (from tensorflow==1.12)
#   Downloading https://files.pythonhosted.org/packages/07/53/8d32ce9471c18f8d99028b7cef2e5b39ea8765bd7ef250ca05b490880971/tensorboard-1.12.2-py3-none-any.whl (3.0MB)
#     100% |████████████████████████████████| 3.1MB 10.6MB/s
# Requirement already satisfied: protobuf>=3.6.1 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.12) (3.7.1)
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (from keras-applications>=1.0.6->tensorflow==1.12) (2.8.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.6/dist-packages (from tensorboard<1.13.0,>=1.12.0->tensorflow==1.12) (3.1)
# Requirement already satisfied: werkzeug>=0.11.10 in /usr/local/lib/python3.6/dist-packages (from tensorboard<1.13.0,>=1.12.0->tensorflow==1.12) (0.15.2)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from protobuf>=3.6.1->tensorflow==1.12) (40.9.0)
# Installing collected packages: tensorboard, tensorflow
#   Found existing installation: tensorboard 1.13.1
#     Uninstalling tensorboard-1.13.1:
#       Successfully uninstalled tensorboard-1.13.1
#   Found existing installation: tensorflow 1.13.1
#     Uninstalling tensorflow-1.13.1:
#       Successfully uninstalled tensorflow-1.13.1
# Successfully installed tensorboard-1.12.2 tensorflow-1.12.0

# %% [markdown]
# ## Imports

# %%
from __future__ import absolute_import, division, print_function

import os
import re

import tensorflow as tf
from tensorflow import keras
import keras.backend as K
print("TensorFlow version is ", tf.__version__)

import numpy as np
import cv2

import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import matplotlib.patches as patches

from google.colab import files
from google.colab import drive

# %matplotlib inline
# Out:
# Using TensorFlow backend.
# TensorFlow version is  1.12.0

# %% [markdown]
# ## Data Preprocessing
# We now need to get access to the data.
#
# Data source: [here](https://www.kaggle.com/c/facial-keypoints-detection/data)

# %% [markdown]
# ### Accessing Data
# We can load the data from Google Drive

# %%
drive.mount('/content/gdrive')
data_path = '/content/gdrive/My Drive/CS 121/TheNoseArcade/Data/facial_keypoints_detection/'
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %% [markdown]
# First, we will define the keypoints we want to import

# %%
keypoint_labels = ['left_eye_center', 'right_eye_center', 'mouth_center_bottom_lip']

# %% [markdown]
# Now we can now set up the loading process

# %%
def gen_keypoint_cols(keypoint_labels):
    '''
    Compute the columns in the spreadsheet where each of the keypoints is located
    '''
    keypoint_cols = np.zeros(len(keypoint_labels)).astype(int)
    header = open(data_path + 'training.csv', 'r').readline()[:-1].split(',')
    img_col = header.index('Image')

    for i in range(len(keypoint_cols)):
        keypoint_cols[i] = header.index(keypoint_labels[i] + '_x')

    return keypoint_cols

# %%
keypoint_cols = gen_keypoint_cols(keypoint_labels)
image_size = 96

# %%
def load_image(source_line, index, image_size):
    '''
    Given a source CSV file line, load the image data and a list of coordinates
    between -1 and 1

    Raises Value Error!
    '''
    global err
    # Prepare the data
    data = source_line[:-1].split(',')
    image_data = [int(pix) for pix in data[img_col].split(' ')]

    # Format the data
    img = np.array(image_data).reshape((image_size, image_size))

    pts = np.zeros(keypoint_cols.shape[0] * 2)
    for i in range(len(keypoint_cols)):
      pts[i * 2] = (float(data[keypoint_cols[i]]) / image_size) * 2 - 1
      pts[i * 2 + 1] = (float(data[keypoint_cols[i] + 1]) / image_size) * 2 - 1

    return img, pts

# %%
def pts_to_coors(pts, image_size):
    '''
    Convert coordinates between -1 and 1 to actual image coordinates
    '''
    return ((pts + 1) / 2) * image_size

# %%
train_csv = open(data_path + 'training.csv', 'r').readlines()[1:]
test_csv = open(data_path + 'test.csv', 'r').readlines()[1:]

# %% [markdown]
# Finally, we can test this on a single image

# %%
img, coors = load_image(train_csv[1], 1, image_size)
plt.imshow(img)
plt.scatter(pts_to_coors(coors[::2], image_size), 
            pts_to_coors(coors[1::2], image_size), c='r')

# %% [markdown]
# ## Create Training and Validation Arrays

# %%
def load_csv(lines, inds, image_size):
    '''
    For a given set of lines from a data csv, return an array of images and an 
    array of labels
    '''
    # Set up arrays
    data = np.ones((len(inds), image_size, image_size))
    labels = np.ones((len(inds), len(keypoint_labels) * 2))

    # Load in the data
    for i in range(inds.shape[0]):
      try:
        data[i], labels[i] = load_image(lines[inds[i]], i, image_size)
      except ValueError:
        # Note: will deal with this issue later
        pass
      
    # Remove zero data, we know that the left eye will never be at (1, 1) or 
    # (96, 96) unless there was no data there
    inds = np.logical_and(labels[:,0] < 1, labels[:,1] < 1)
    data = data[inds]
    labels = labels[inds]
        
    data = np.repeat(data[..., np.newaxis], 3, -1).astype(int)

    return data, labels

# %% [markdown]
# Now decide which indicies to use for training and which to use for validation. We will reserve 100 images for validation.

# %%
all_inds = np.arange(len(train_csv))
valid_inds = np.random.choice(all_inds, size=100, replace=False)
train_inds = all_inds[np.logical_not(np.isin(all_inds, valid_inds))]

# %%
train_data, train_labels = load_csv(train_csv, train_inds, image_size)
valid_data, valid_labels = load_csv(train_csv, valid_inds, image_size)

# %% [markdown]
# Finally make sure everything is okay by displaying an image

# %%
i = 200
plt.imshow(train_data[i])
plt.scatter([pts_to_coors(train_labels[i][::2], image_size)], 
            [pts_to_coors(train_labels[i][1::2], image_size)], c='r')

# %% [markdown]
# ### Create Image Data Generator with Image Augmentation
# We then need to resize the images and create a data generator, to be used for training / validation
#
# For this section, I used an additional source: [here](https://keras.io/preprocessing/image/)

# %%
def create_datagens(train_data, train_labels, valid_data, valid_labels):
    # Rescale all images by 1./255 and apply image augmentation
    train_datagen = keras.preprocessing.image.ImageDataGenerator(rescale=1./255)

    validation_datagen = keras.preprocessing.image.ImageDataGenerator(rescale=1./255)

    # Flow training images in batches of 32 using train_datagen generator
    train_generator = train_datagen.flow(train_data, train_labels,
                    batch_size=batch_size)

    # Flow validation images in batches of 32 using test_datagen generator
    validation_generator = validation_datagen.flow(valid_data, valid_labels,
                    batch_size=batch_size)
    
    return train_generator, validation_generator

# %%
batch_size = 64
train_generator, validation_generator = \
  create_datagens(train_data, train_labels, valid_data, valid_labels)

# %% [markdown]
# ## Model Set-Up

# %% [markdown]
# ### Create the base model using a pretrained network
# Here we are using MobileNet, but that can always be changed.

# %%
IMG_SHAPE = (image_size, image_size, 3)

# Create the base model from the pre-trained model MobileNet
base_model = tf.keras.applications.MobileNetV2(include_top=False,
                                            input_shape=IMG_SHAPE, 
                                            weights='imagenet')

# %% [markdown]
# ### Freeze the convolutional base
# We will freeze the convolutional base created from the previous step and use that as a feature extractor, add a classifier on top of it and train the top-level classifier.
#
# It's important to freeze the convolutional based before we compile and train the model. By freezing (or setting layer.trainable = False), we prevent the weights in these layers from being updated during training.

# %%
base_model.trainable = False

# %% [markdown]
# ### Now create the model to store the layers for identified facial features

# %%
def create_feat_model():
    '''
    Create a model to store the layers for identified facial features
    '''
    feats = tf.keras.Input(shape=(3, 3, 1280))
    pool = tf.keras.layers.GlobalAveragePooling2D()(feats)
    dense1 = tf.keras.layers.Dense(1024, activation=tf.keras.activations.relu)(pool)
    drop = tf.keras.layers.Dropout(0.1)(dense1)
    dense2 = tf.keras.layers.Dense(len(keypoint_labels) * 2)(drop)
    
    return tf.keras.Model(inputs=feats, outputs=dense2)

# %%
feat_model = create_feat_model()

# %% [markdown]
# ### Add back the top layers
# Now let's add a few layers on top of the base model:

# %%
model = tf.keras.Sequential([
    base_model,
    feat_model
])

# %% [markdown]
# ### Compile the model
# You must compile the model before training it. For this, we will create a new metric, the distance between the ground-truth point and our point

# %%
def dist_pred(y_true, y_pred):
    sum_dist = 0
    for i in range(len(keypoint_labels)):
        sum_dist = K.sqrt((y_true[i * 2] - y_pred[i * 2])**2 + (y_true[i * 2 + 1] - y_pred[i * 2 + 1])**2)
    return sum_dist * image_size

# %%
lr = 0.0001 # 0.0001
model.compile(optimizer=tf.keras.optimizers.RMSprop(lr=lr), 
              loss='mean_squared_error', 
              metrics=[dist_pred])

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# mobilenetv2_1.00_96 (Model)  (None, 3, 3, 1280)        2257984
# _________________________________________________________________
# model_3 (Model)              (None, 6)                 1317894
# =================================================================
# Total params: 3,575,878
# Trainable params: 1,317,894
# Non-trainable params: 2,257,984
# _________________________________________________________________

# %% [markdown]
# ### Train Top Layers

# %%
def train(lr, epochs):
  model.compile(optimizer=tf.keras.optimizers.RMSprop(lr=lr), 
              loss='mean_squared_error', 
              metrics=[dist_pred])
  steps_per_epoch = train_generator.n // batch_size
  validation_steps = max(validation_generator.n // batch_size, 1)

  history = model.fit_generator(train_generator, 
                                steps_per_epoch = steps_per_epoch,
                                epochs=epochs, 
                                workers=4,
                                validation_data=validation_generator, 
                                validation_steps=validation_steps)

# %%
epochs = 1
lr = 0.0001 # 0.0001
train(lr, epochs)
# Out:
# Epoch 1/1
# 107/107 [==============================] - 169s 2s/step - loss: 0.2309 - dist_pred: 56.2787 - val_loss: 0.1287 - val_dist_pred: 46.6283

# %%
epochs = 1
lr = 0.0001 # 0.0001
train(lr, epochs)
# Out:
# Epoch 1/1
# 107/107 [==============================] - 168s 2s/step - loss: 0.0672 - dist_pred: 31.4599 - val_loss: 0.0596 - val_dist_pred: 36.3813

# %%
epochs = 1
lr = 0.0001 # 0.0001
train(lr, epochs)
# Out:
# Epoch 1/1
# 107/107 [==============================] - 167s 2s/step - loss: 0.0244 - dist_pred: 18.3552 - val_loss: 0.0293 - val_dist_pred: 23.9400

# %%
epochs = 1
lr = 0.0001 # 0.0001
train(lr, epochs)
# Out:
# Epoch 1/1
# 107/107 [==============================] - 170s 2s/step - loss: 0.0135 - dist_pred: 13.8299 - val_loss: 0.0241 - val_dist_pred: 24.7851

# %% [markdown]
# We can try out the results of our model

# %%
i = 30
pts = model.predict(np.expand_dims(valid_data[i], axis=0))
plt.imshow(valid_data[i])
plt.scatter(pts_to_coors(pts[0][::2], image_size), 
            pts_to_coors(pts[0][1::2], image_size), c='r')

# %% [markdown]
# ## Estimate Nose Position
# Now, we can use the layers we have generated to use the other facial features to estimate nose position

# %% [markdown]
# ### Reload Data
# We need to reload the data to get the nose-tip data

# %%
keypoint_labels = ['nose_tip']
keypoint_cols = gen_keypoint_cols(keypoint_labels)

# %% [markdown]
# We do not what to change which images we use for training and which we use for validation, but we do want to re-generate the labels so that they only contain the nose tip. We first load the labels and then create the generators

# %%
train_data, train_labels = load_csv(train_csv, train_inds)
valid_data, valid_labels = load_csv(train_csv, valid_inds)

# %%
train_generator, validation_generator = \
  create_datagens(train_data, train_labels, valid_data, valid_labels)

# %% [markdown]
# ### Freeze Feature Model
# We now just want to train a set of weights to take the facial features and compute the nose position

# %%
feat_model.trainable = False

# %% [markdown]
# ### Add Nose Estimation Layer

# %%
model = tf.keras.Sequential([
    base_model,
    feat_model,
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dense(2)
])

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# mobilenetv2_1.00_96 (Model)  (None, 3, 3, 1280)        2257984
# _________________________________________________________________
# model_1 (Model)              (None, 6)                 1317894
# _________________________________________________________________
# batch_normalization (BatchNo (None, 6)                 24
# _________________________________________________________________
# dense_5 (Dense)              (None, 2)                 14
# =================================================================
# Total params: 3,575,916
# Trainable params: 26
# Non-trainable params: 3,575,890
# _________________________________________________________________

# %% [markdown]
# ### Train Final Layer

# %%
epochs = 1
lr = 0.0001 # 0.0001
train(lr, epochs)
# Out:
# Epoch 1/1
#  71/108 [==================>...........] - ETA: 1:11 - loss: 3158.2590 - dist_pred: 78.7695
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-79-d0cdb2f55794> in <module>()
#       1 epochs = 1
#       2 lr = 0.0001 # 0.0001
# ----> 3 train(lr, epochs)
#
# <ipython-input-57-97327da5e56c> in train(lr, epochs)
#      11                                 workers=4,
#      12                                 validation_data=validation_generator,
# ---> 13                                 validation_steps=validation_steps)
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/training.py in fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#    2175         use_multiprocessing=use_multiprocessing,
#    2176         shuffle=shuffle,
# -> 2177         initial_epoch=initial_epoch)
#    2178
#    2179   def evaluate_generator(self,
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/training_generator.py in fit_generator(model, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#     174
#     175         outs = model.train_on_batch(
# --> 176             x, y, sample_weight=sample_weight, class_weight=class_weight)
#     177
#     178         if not isinstance(outs, list):
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/training.py in train_on_batch(self, x, y, sample_weight, class_weight)
#    1938
#    1939       self._make_train_function()
# -> 1940       outputs = self.train_function(ins)
#    1941
#    1942     if len(outputs) == 1:
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/backend.py in __call__(self, inputs)
#    2984
#    2985     fetched = self._callable_fn(*array_vals,
# -> 2986                                 run_metadata=self.run_metadata)
#    2987     self._call_fetch_callbacks(fetched[-len(self._fetches):])
#    2988     return fetched[:len(self.outputs)]
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/client/session.py in __call__(self, *args, **kwargs)
#    1437           ret = tf_session.TF_SessionRunCallable(
#    1438               self._session._session, self._handle, args, status,
# -> 1439               run_metadata_ptr)
#    1440         if run_metadata:
#    1441           proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# KeyboardInterrupt:

# %% [markdown]
# ## Testing
# We can also try this out on other data sets

# %%
gt_db_path = '/content/gdrive/My Drive/CS 121/TheNoseArcade/Data/gt_db/'

# %%
image = cv2.imread(gt_db_path + 's01/05.jpg')
grayscale_image = cv2.cvtColor(image, cv2.COLOR_RGB2GRAY)
face_cascade = cv2.CascadeClassifier('/content/gdrive/My Drive/CS 121/TheNoseArcade/Data/haarcascade_frontalface_default.xml')
box = face_cascade.detectMultiScale(grayscale_image, 1.25, 6)[0]

# %%
net_data = cv2.resize(image[box[1]:(box[1]+box[3]), box[0]:(box[0] + box[2]), :], (image_size, image_size))
pts = model.predict(np.expand_dims(net_data, axis=0))

# %%
fig,ax = plt.subplots(1)
ax.imshow(image)
rect = patches.Rectangle((box[0], box[1]), box[2], box[3], linewidth=1, 
                         edgecolor='g', facecolor='none')
ax.add_patch(rect)
ax.scatter(box[0] + pts[0][::2] * box[2] / image_size, 
           box[1] + pts[0][1::2] * box[3] / image_size, c='r')

plt.show()

# %% [markdown]
# ## Saving the Model
# First recompile the model so that it no longer uses the distance measure, confirm that it is still working (rerun above), and save it

# %%
model.compile(optimizer=tf.keras.optimizers.RMSprop(lr=0.0001), 
              loss='mean_squared_error', 
              metrics=[])

# %%
model.save('eyes_mouth.h5')
files.download('eyes_mouth.h5')
